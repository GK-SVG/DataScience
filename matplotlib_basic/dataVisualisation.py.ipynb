# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
exams = pd.read_csv('exams2.csv')
print(exams.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B          associate's degree      standard
# 1  female        group D                 high school  free/reduced
# 2    male        group B                some college  free/reduced
# 3    male        group E             master's degree      standard
# 4    male        group B             master's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          66             79             76
# 1                    none          80             86             83
# 2               completed          76             80             79
# 3               completed          85             74             75
# 4                    none          72             64             64

# %%
plt.hist(exams['math score'],bins=15)
plt.grid(True)
plt.show()

# %%
fruits = ['pepsi','dew','mirinda','slice','coke','sprite']
cost = [60,60,55,70,45,50]
plt.pie(cost,labels=fruits,autopct='%0.1f%%')
plt.show()
