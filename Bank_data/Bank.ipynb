# %%
import pandas as pd
bank = pd.read_csv('bank_branches.csv')
bank.head()
# Out:
#           ifsc  bank_id           branch  \
# 0  ABHY0065001       60          RTGS-HO
# 1  ABHY0065002       60  ABHYUDAYA NAGAR
# 2  ABHY0065003       60       BAIL BAZAR
# 3  ABHY0065004       60          BHANDUP
# 4  ABHY0065005       60        DARUKHANA
#
#                                              address    city        district  \
# 0  ABHYUDAYA BANK BLDG., B.NO.71, NEHRU NAGAR, KU...  MUMBAI  GREATER MUMBAI
# 1  ABHYUDAYA EDUCATION SOCIETY, OPP. BLDG. NO. 18...  MUMBAI  GREATER MUMBAI
# 2  KMSPM'S SCHOOL, WADIA ESTATE, BAIL BAZAR-KURLA...  MUMBAI  GREATER MUMBAI
# 3  CHETNA APARTMENTS, J.M.ROAD, BHANDUP, MUMBAI-4...  MUMBAI  GREATER MUMBAI
# 4  POTIA IND.ESTATE, REAY ROAD (E), DARUKHANA, MU...  MUMBAI  GREATER MUMBAI
#
#          state                           bank_name
# 0  MAHARASHTRA  ABHYUDAYA COOPERATIVE BANK LIMITED
# 1  MAHARASHTRA  ABHYUDAYA COOPERATIVE BANK LIMITED
# 2  MAHARASHTRA  ABHYUDAYA COOPERATIVE BANK LIMITED
# ...

# %%
bank.tail()
# Out:
#                ifsc  bank_id       branch                             address  \
# 127852  ZSBL0000301      101      BHOJPUR                   BHOJPUR MODINAGAR
# 127853  ZSBL0000311      101   VIJAYNAGAR  B 1,SEC 12 PRATAP VIHAR VIJAYNAGAR
# 127854  ZSBL0000321      101        KHORA                  KHODA COLONY KHODA
# 127855  ZSBL0000331      101  RAVALI KALA          VILL.RAVLIKALA,MURAD NAGAR
# 127856  ZSBL0000341      101         LONI    HANSH AUTO MOBILS LONI GHAZIABAD
#
#              city   district          state  \
# 127852  MODINAGAR  GHAZIABAD  UTTAR PRADESH
# 127853  GHAZIABAD  GHAZIABAD  UTTAR PRADESH
# 127854  GHAZIABAD  GHAZIABAD  UTTAR PRADESH
# 127855      RAVLI  GHAZIABAD  UTTAR PRADESH
# 127856       LONI  GHAZIABAD  UTTAR PRADESH
#
#                                   bank_name
# 127852  ZILA SAHAKRI BANK LIMITED GHAZIABAD
# 127853  ZILA SAHAKRI BANK LIMITED GHAZIABAD
# 127854  ZILA SAHAKRI BANK LIMITED GHAZIABAD
# 127855  ZILA SAHAKRI BANK LIMITED GHAZIABAD
# ...

# %%
bank.head(50)
# Out:
#            ifsc  bank_id           branch  \
# 0   ABHY0065001       60          RTGS-HO
# 1   ABHY0065002       60  ABHYUDAYA NAGAR
# 2   ABHY0065003       60       BAIL BAZAR
# 3   ABHY0065004       60          BHANDUP
# 4   ABHY0065005       60        DARUKHANA
# 5   ABHY0065006       60             FORT
# 6   ABHY0065007       60        GHATKOPAR
# 7   ABHY0065008       60           KANJUR
# 8   ABHY0065009       60      NEHRU NAGAR
# 9   ABHY0065010       60            PAREL
# 10  ABHY0065011       60            SEWRI
# 11  ABHY0065012       60           WADALA
# 12  ABHY0065013       60            WORLI
# 13  ABHY0065014       60           MUMBRA
# 14  ABHY0065015       60           TURBHE
# 15  ABHY0065016       60            VASHI
# 16  ABHY0065017       60      MOBILE BANK
# 17  ABHY0065018       60       NEW PANVEL
# 18  ABHY0065019       60        KALAMBOLI
# 19  ABHY0065020       60          DHARAVI
# 20  ABHY0065021       60       MALAD EAST
# ...
